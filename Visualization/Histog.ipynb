# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
Data = list(map(lambda _: random.randint(0,100),range(100)))

# %%
class MyHistor:
  def __init__(self,Data,bin):
    self.Data = Data
    self.bin = bin

  def Histogram(self):

    plt.hist(self.Data,self.bin,color = "skyblue",edgecolor = "black" )
    plt.title("This is Myhistrogram")
    plt.xlabel("Random out_put from 0 to 100")
    plt.ylabel("Count")

# histogram = MyHistor(Data,10)
# histogram.Histogram()
bin = np.arange(0,100,7)
histogram = MyHistor(Data,bin)
histogram.Histogram()
