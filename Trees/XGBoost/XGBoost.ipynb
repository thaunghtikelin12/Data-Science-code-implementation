# %% [markdown]
# Need to Learn XGBoost and

# %%
# !pip install importnb
# Out:
# Requirement already satisfied: importnb in /usr/local/lib/python3.11/dist-packages (2023.11.1)

# %%
# !pip install importnb
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Requirement already satisfied: importnb in /usr/local/lib/python3.11/dist-packages (2023.11.1)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/portfolio/Trees/Random_Forest")
from importnb import Notebook
with Notebook():
  from Random_Forest import MyRandomforest
# Out:
# Requirement already satisfied: importnb in /usr/local/lib/python3.11/dist-packages (2023.11.1)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Hello

# %%
from xgboost import XGBClassifier
class MyXGBoost(MyRandomforest):
  def __init__(self):
    super().__init__()

  def myXgbostmodel(self):
    self.model = XGBClassifier(gamma = 0,learning_rate = 0.01 , max_depth = 10, n_estimators = 1000 , random_state = 42, eval_metric = "logloss")
    self.model.fit(self.X_train,self.y_train)

# %%
fitforData = MyXGBoost()

# %%
fitforData.FileRead()
fitforData.Splicdata()
fitforData.databalance()
fitforData.myXgbostmodel()#default of maxdepth is 6
fitforData.F1_score()
# Out:
# Enter Your file path : /content/drive/MyDrive/Colab Notebooks/portfolio/Trees/XGBoost/heart_stroke_update.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  float64
#  1   HighBP                253680 non-null  float64
#  2   HighChol              253680 non-null  float64
#  3   CholCheck             253680 non-null  float64
#  4   Smoker                253680 non-null  float64
#  5   Stroke                253680 non-null  float64
#  6   PhysActivity          253680 non-null  float64
#  7   Fruits                253680 non-null  float64
#  8   Veggies               253680 non-null  float64
#  9   HvyAlcoholConsump     253680 non-null  float64
#  10  AnyHealthcare         253680 non-null  float64
#  11  NoDocbcCost           253680 non-null  float64
#  12  DiffWalk              253680 non-null  float64
#  13  Sex                   253680 non-null  float64
#  14  BMI_flag1             253680 non-null  int64
#  15  BMI_flag2             253680 non-null  int64
#  16  BMI_flag3             253680 non-null  int64
#  17  BMI_flag4             253680 non-null  int64
#  18  Age_flag1             253680 non-null  int64
#  19  Age_flag2             253680 non-null  int64
#  20  Age_flag3             253680 non-null  int64
#  21  MentHlth_flag1        253680 non-null  int64
#  22  MentHlth_flag2        253680 non-null  int64
#  23  MentHlth_flag3        253680 non-null  int64
#  24  PhysHlth_flag1        253680 non-null  int64
#  25  PhysHlth_flag2        253680 non-null  int64
#  26  PhysHlth_flag3        253680 non-null  int64
#  27  GenHlth_flag1         253680 non-null  int64
#  28  GenHlth_flag2         253680 non-null  int64
#  29  GenHlth_flag3         253680 non-null  int64
#  30  GenHlth_flag4         253680 non-null  int64
#  31  GenHlth_flag5         253680 non-null  int64
#  32  Diabetes_flag1        253680 non-null  int64
#  33  Diabetes_flag2        253680 non-null  int64
#  34  Diabetes_flag3        253680 non-null  int64
# dtypes: float64(14), int64(21)
# memory usage: 67.7 MB
# None
# (253680, 34)
# This is confusion metrix :  [[22766   213]
#  [21641  1338]]
# This is F1 score for train :  0.267684360664585
# This is F1 score for test :  0.10909090909090909

# %%
# Out:
# Class distribution in training set:
# [206808  21504]

# %%
# from xgboost import XGBClassifier

# model = XGBClassifier(n_estimators=1000)  # high upper limit
# model.fit(
#     X_train, y_train,
#     early_stopping_rounds=50,
#     eval_set=[(X_val, y_val)],
#     eval_metric="logloss",
#     verbose=False
# )

#     Trains up to 1000 trees, but stops early if the validation score doesn't improve for 50 rounds.

# %%
# from google.colab import drive
# drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# import pandas as pd
# import numpy as np
# import xgboost as xgb
# from xgboost import XGBClassifier
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import accuracy_score,recall_score,precision_score

# %%
# def recallex(y_pre,y_true):
#   num = len(y_true)
#   FP = 0
#   FN = 0
#   TP = 0
#   TN = 0
#   for i in range(num):
#     if y_pre[i] == 0 and y_true[i]== 0:
#       TN +=1
#     if y_pre[i] == 0 and y_true[i]== 1:
#       FN +=1
#     if y_pre[i] == 1 and y_true[i]== 1:
#       TP +=1
#     elif y_pre[i] == 1 and y_true[i]== 0:
#       FP +=1

#   print(f' TN : {TN} \n FN : {FN} \n TP : {TP} \n FP : {FP}    ')

# def result(X_train):
#   predictions = model.predict(X_train)
#   custom_threshold = 0.5

# # Apply custom threshold to sigmoid output
#   predict = (predictions >= custom_threshold).astype(int)
#   return predict

# %%
# df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/Trees/XGBoost/heart_stroke_update.csv")

# %%
# df.info()
# df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253680 entries, 0 to 253679
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   HeartDiseaseorAttack  253680 non-null  float64
#  1   HighBP                253680 non-null  float64
#  2   HighChol              253680 non-null  float64
#  3   CholCheck             253680 non-null  float64
#  4   Smoker                253680 non-null  float64
#  5   Stroke                253680 non-null  float64
#  6   PhysActivity          253680 non-null  float64
#  7   Fruits                253680 non-null  float64
#  8   Veggies               253680 non-null  float64
#  9   HvyAlcoholConsump     253680 non-null  float64
#  10  AnyHealthcare         253680 non-null  float64
#  11  NoDocbcCost           253680 non-null  float64
#  12  DiffWalk              253680 non-null  float64
#  13  Sex                   253680 non-null  float64
#  14  BMI_flag1             253680 non-null  int64
#  15  BMI_flag2             253680 non-null  int64
#  16  BMI_flag3             253680 non-null  int64
#  17  BMI_flag4             253680 non-null  int64
#  18  Age_flag1             253680 non-null  int64
#  19  Age_flag2             253680 non-null  int64
#  20  Age_flag3             253680 non-null  int64
#  21  MentHlth_flag1        253680 non-null  int64
#  22  MentHlth_flag2        253680 non-null  int64
#  23  MentHlth_flag3        253680 non-null  int64
#  24  PhysHlth_flag1        253680 non-null  int64
#  25  PhysHlth_flag2        253680 non-null  int64
#  26  PhysHlth_flag3        253680 non-null  int64
#  27  GenHlth_flag1         253680 non-null  int64
#  28  GenHlth_flag2         253680 non-null  int64
#  29  GenHlth_flag3         253680 non-null  int64
#  30  GenHlth_flag4         253680 non-null  int64
#  31  GenHlth_flag5         253680 non-null  int64
#  32  Diabetes_flag1        253680 non-null  int64
#  33  Diabetes_flag2        253680 non-null  int64
#  34  Diabetes_flag3        253680 non-null  int64
# dtypes: float64(14), int64(21)
# memory usage: 67.7 MB
# Index(['HeartDiseaseorAttack', 'HighBP', 'HighChol', 'CholCheck', 'Smoker',
#        'Stroke', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump',
#        'AnyHealthcare', 'NoDocbcCost', 'DiffWalk', 'Sex', 'BMI_flag1',
#        'BMI_flag2', 'BMI_flag3', 'BMI_flag4', 'Age_flag1', 'Age_flag2',
#        'Age_flag3', 'MentHlth_flag1', 'MentHlth_flag2', 'MentHlth_flag3',
#        'PhysHlth_flag1', 'PhysHlth_flag2', 'PhysHlth_flag3', 'GenHlth_flag1',
#        'GenHlth_flag2', 'GenHlth_flag3', 'GenHlth_flag4', 'GenHlth_flag5',
#        'Diabetes_flag1', 'Diabetes_flag2', 'Diabetes_flag3'],
#       dtype='object')

# %%
# X = np.array(df[['HighBP', 'HighChol', 'CholCheck', 'Smoker',
#        'Stroke', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump',
#        'AnyHealthcare', 'NoDocbcCost', 'DiffWalk', 'Sex', 'BMI_flag1',
#        'BMI_flag2', 'BMI_flag3', 'BMI_flag4', 'Age_flag1', 'Age_flag2',
#        'Age_flag3', 'MentHlth_flag1', 'MentHlth_flag2', 'MentHlth_flag3',
#        'PhysHlth_flag1', 'PhysHlth_flag2', 'PhysHlth_flag3', 'GenHlth_flag1',
#        'GenHlth_flag2', 'GenHlth_flag3', 'GenHlth_flag4', 'GenHlth_flag5',
#        'Diabetes_flag1', 'Diabetes_flag2', 'Diabetes_flag3']])
# y = np.array(df["HeartDiseaseorAttack"])

# %%
# X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.8,random_state=42)

# %%
# model = XGBClassifier(n_estimators=100, learning_rate=0.1, random_state=42, eval_metric="logloss")

# %%
# model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, random_state=42, ...)

# %%
# y_pre = model.predict(X_train)
# acc_score = accuracy_score(y_train,y_pre)
# print(f"The accuracy score of train data is {acc_score:.2f}")
# recallex(y_pre,y_test)
# y_pre = model.predict(X_test)
# acc_score = accuracy_score(y_test,y_pre)
# print(f"The accuracy score of test is {acc_score:.2f}")
# recallex(y_pre,y_test)
# Out:
# The accuracy score of train data is 0.91
#  TN : 45278
#  FN : 4696
#  TP : 72
#  FP : 690
# The accuracy score of test is 0.91
#  TN : 45626
#  FN : 4341
#  TP : 427
#  FP : 342

# %%
# y_pre = model.predict(X_train)
# acc_score = accuracy_score(y_train,y_pre)
# print(f"The accuracy score of train data is {acc_score:.2f}")
# recallex(y_pre,y_test)
# y_pre = model.predict(X_test)
# acc_score = accuracy_score(y_test,y_pre)
# print(f"The accuracy score of test is {acc_score:.2f}")
# recallex(y_pre,y_test)
# Out:
# The accuracy score of train data is 0.91
#  TN : 45278
#  FN : 4696
#  TP : 72
#  FP : 690
# The accuracy score of test is 0.91
#  TN : 45626
#  FN : 4341
#  TP : 427
#  FP : 342

# %%
# from sklearn.metrics import classification_report

# print("Training Data Classification Report:")
# print(classification_report(y_train, model.predict(X_train)))

# print("\nTest Data Classification Report:")
# print(classification_report(y_test, model.predict(X_test)))
# Out:
# Training Data Classification Report:

# %%
# from xgboost import XGBClassifier
# from sklearn.utils import compute_class_weight
# import numpy as np

# class MyXGBoost(MyRandomforest):
#     def __init__(self):
#         super().__init__()

#     def myXgbostmodel(self):
#         # Compute scale_pos_weight for binary classification
#         classes = np.unique(self.y_train)
#         class_weights = compute_class_weight(class_weight='balanced', classes=classes, y=self.y_train)

#         if len(classes) == 2:
#             scale_pos_weight = class_weights[0] / class_weights[1]  # majority / minority
#         else:
#             scale_pos_weight = 1  # don't apply if not binary

#         self.model = XGBClassifier(
#             gamma=0,
#             learning_rate=0.01,
#             max_depth=6,
#             n_estimators=1000,  # Increased from 100
#             scale_pos_weight=scale_pos_weight,
#             subsample=0.8,
#             colsample_bytree=0.8,
#             use_label_encoder=False,
#             random_state=42,
#             eval_metric="logloss"
#         )

#         self.model.fit(self.X_train, self.y_train)
