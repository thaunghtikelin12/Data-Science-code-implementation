# %% [markdown]
# **My Modify Coded using Random_Forest model . A little improvement but not good  hmm go ahead my boy**

# %%
# !pip install importnb

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
sys.path.append("/content/drive/MyDrive/Colab Notebooks/portfolio/Trees/Decision_Tree")
from importnb import Notebook
with Notebook():
  from Decision_tree import MyDecisionTree
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
class Hello:
  print("Hello")
# Out:
# Hello

# %%
from sklearn.ensemble import RandomForestClassifier
from imblearn.over_sampling import SMOTE
class MyRandomforest(MyDecisionTree):
  def __init__(self):
        super().__init__()
  def myRandomforestmodel(self):
    self.model = RandomForestClassifier(criterion = "entropy" , class_weight = "balanced")
    self.model.fit(self.X_train,self.y_train)
  def databalance(self):
    sm = SMOTE(random_state = 42 )
    self.X_test,self.y_test = sm.fit_resample(self.X_test,self.y_test)
    print(self.X.shape)

# %%
# fitforRandomforest = MyRandomforest()
# fitforRandomforest.FileRead()
# fitforRandomforest.Splicdata()
# fitforRandomforest.databalance()
# fitforRandomforest.myRandomforestmodel()
# fitforRandomforest.F1_score()

# %%
# from google.colab import drive
# drive.mount("/content/drive")

# %%
# import pandas as pd
# import numpy as np
# from sklearn.model_selection import train_test_split
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import accuracy_score,precision_score,recall_score

# %%
# # df = pd.read_csv("heart_stroke_update.csv")
# # Shareddrives
# df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/Trees/Random Forest/heart_stroke_update.csv" )

# %%
# def recallex(y_pre,y_true):
#   num = len(y_true)
#   FP = 0
#   FN = 0
#   TP = 0
#   TN = 0
#   for i in range(num):
#     if y_pre[i] == 0 and y_true[i]== 0:
#       TN +=1
#     if y_pre[i] == 0 and y_true[i]== 1:
#       FN +=1
#     if y_pre[i] == 1 and y_true[i]== 1:
#       TP +=1
#     elif y_pre[i] == 1 and y_true[i]== 0:
#       FP +=1

#   print(f' TN : {TN} \n FN : {FN} \n TP : {TP} \n FP : {FP}    ')

# def result(X_train):
#   predictions = model.predict(X_train)
#   custom_threshold = 0.5

# # Apply custom threshold to sigmoid output
#   predict = (predictions >= custom_threshold).astype(int)
#   return predict

# %%
# df.columns

# %%
# X = np.array(df[[ 'HighBP', 'HighChol', 'CholCheck', 'Smoker',
#        'Stroke', 'PhysActivity', 'Fruits', 'Veggies', 'HvyAlcoholConsump',
#        'AnyHealthcare', 'NoDocbcCost', 'DiffWalk', 'Sex', 'BMI_flag1',
#        'BMI_flag2', 'BMI_flag3', 'BMI_flag4', 'Age_flag1', 'Age_flag2',
#        'Age_flag3', 'MentHlth_flag1', 'MentHlth_flag2', 'MentHlth_flag3',
#        'PhysHlth_flag1', 'PhysHlth_flag2', 'PhysHlth_flag3', 'GenHlth_flag1',
#        'GenHlth_flag2', 'GenHlth_flag3', 'GenHlth_flag4', 'GenHlth_flag5',
#        'Diabetes_flag1', 'Diabetes_flag2', 'Diabetes_flag3']])
# y = np.array(df['HeartDiseaseorAttack'])

# %%
# X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,test_size=0.2)

# %%
# model = RandomForestClassifier(n_estimators=80,random_state=42,criterion="gini")

# %%
# model.fit(X_train,y_train)

# %%
# y_pre = model.predict(X_train)
# acc_score = accuracy_score(y_train,y_pre)
# print(f"The accuracy score of train data is {acc_score:.2f}")
# recallex(y_pre,y_test)
# y_pre = model.predict(X_test)
# acc_score = accuracy_score(y_test,y_pre)
# print(f"The accuracy score of test is {acc_score:.2f}")
# recallex(y_pre,y_test)

# %%
# y_pre = model.predict(X_train)
# acc_score = accuracy_score(y_train,y_pre)
# print(f"The accuracy score of train data is {acc_score:.2f}")
# recallex(y_pre,y_test)
# y_pre = model.predict(X_test)
# acc_score = accuracy_score(y_test,y_pre)
# print(f"The accuracy score of test is {acc_score:.2f}")
# recallex(y_pre,y_test)
