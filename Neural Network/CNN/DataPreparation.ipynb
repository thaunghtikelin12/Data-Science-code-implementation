# %%
import numpy as np
import pandas as pd
import os
from google.colab import drive
from PIL import Image

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
folder_path = f"/content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors"

# %%
lis1 = ["yellow","white","red","purple","orange","green","brown","blue","black"]
image_arrays = []
for i in lis1:
  folder_path = f"/content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/{i}"
  print(folder_path)
  for filename in os.listdir(folder_path):
    image_path = os.path.join(folder_path,filename)
    image_array = Image.open(image_path)
    image_arrays.append(image_array)
# Out:
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/yellow
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/white
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/red
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/purple
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/orange
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/green
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/brown
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/blue
# /content/drive/MyDrive/Colab Notebooks/portfolio/Datasets/colordata_set/dataset_colors/black

# %%
image_arrays[1]

# %%
image_arrays[10]
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512>
