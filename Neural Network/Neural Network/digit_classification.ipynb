# %%
import pandas as pd

# %%
final_digital_file = [f"standard_digit_{i}.csv" for i in range(10)]
sampled_data = pd.DataFrame()
final_digital_file
# Out:
# ['standard_digit_0.csv',
#  'standard_digit_1.csv',
#  'standard_digit_2.csv',
#  'standard_digit_3.csv',
#  'standard_digit_4.csv',
#  'standard_digit_5.csv',
#  'standard_digit_6.csv',
#  'standard_digit_7.csv',
#  'standard_digit_8.csv',
#  'standard_digit_9.csv']

# %%
for files in final_digital_file:
  print(files)
  df = pd.read_csv(files)
  sampled_data = pd.concat([sampled_data,df], ignore_index=True)
# Out:
# standard_digit_0.csv
# standard_digit_1.csv
# standard_digit_2.csv
# standard_digit_3.csv
# standard_digit_4.csv
# standard_digit_5.csv
# standard_digit_6.csv
# standard_digit_7.csv
# standard_digit_8.csv
# standard_digit_9.csv

# %%
sampled_data.to_csv("final_digital_file.csv",index=False)

# %%
digits = range(10)

# DataFrame to hold all sampled data
sampled_data = pd.DataFrame()

for digit in digits:
    # Read the CSV file
    sampled_df = pd.read_csv(rf'digits_{digit}.csv')

    # Sample 1000 rows
    # sampled_df = df.sample(n=1000, random_state=1)

    # Append to the final DataFrame
    sampled_data = pd.concat([sampled_data, sampled_df], ignore_index=True)

# Save the final DataFrame to a new CSV file
sampled_data.to_csv(r'sampled_data.csv', index=False)
