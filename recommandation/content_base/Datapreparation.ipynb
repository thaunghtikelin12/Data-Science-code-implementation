# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/recommandation/content_base/content_base/moviess.csv")

# %%
ddf = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/recommandation/content_base/content_base/movies.csv")

# %%
print(ddf.columns)
print(df.columns)
# Out:
# Index(['movieId', 'title', 'genres1', 'genres2', 'genres3', 'genres4',
#        'genres5', 'genres6', 'genres7', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11'],
#       dtype='object')
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
# # for i in range(df.count()[1]):
# #   print(df.loc[i].genres)
# genres = []
# for i in ddf.columns[2:]:
#   column_genres = list(ddf[i].unique())
#   for j in column_genres:
#     if j not in genres:
#       genres.append(j)
# for i in genres:
#   print(i)
#   print(type(i))

# %%
# # newgenres = sorted(genres)
# removeList = ["(no","genres","listed)"]
# print(genres)
# for i in removeList:
#   print(i)
#   genres.remove(i)

# %%
# genres.remove(genres[-1])

# %%
# genres

# %%
hello = ["Fantasy"]
if "Comedy|Fantasy" in hello:
  print("hello")
else:
    print("fales")
# Out:
# fales

# %%
for i in genres:
  df[i] = np.nan

# %%
df.columns

# %%
count = 0
for i in df["genres"]:
  print(count)
  for j in genres:
    if j in i:

      df.at[count,j] = 1
    else:
      df.loc[count,j] = 0
  count += 1
# Out:
# Streaming output truncated to the last 5000 lines.
# 57423
# 57424
# 57425
# 57426
# 57427
# 57428
# 57429
# 57430
# 57431
# 57432
# 57433
# 57434
# 57435
# 57436
# 57437
# 57438
# 57439
# 57440
# 57441
# 57442
# 57443
# 57444
# 57445
# 57446
# 57447
# 57448
# 57449
# 57450
# 57451
# 57452
# 57453
# 57454
# 57455
# 57456
# 57457
# 57458
# 57459
# 57460
# 57461
# 57462
# 57463
# 57464
# 57465
# 57466
# 57467
# 57468
# 57469
# 57470
# 57471
# 57472
# 57473
# 57474
# 57475
# 57476
# 57477
# 57478
# 57479
# 57480
# 57481
# 57482
# 57483
# 57484
# 57485
# 57486
# 57487
# 57488
# 57489
# 57490
# 57491
# 57492
# 57493
# 57494
# 57495
# 57496
# 57497
# 57498
# 57499
# 57500
# 57501
# 57502
# 57503
# 57504
# 57505
# 57506
# 57507
# 57508
# 57509
# 57510
# 57511
# 57512
# 57513
# 57514
# 57515
# 57516
# 57517
# 57518
# 57519
# 57520
# 57521
# 57522
# 57523
# 57524
# 57525
# 57526
# 57527
# 57528
# 57529
# 57530
# 57531
# 57532
# 57533
# 57534
# 57535
# 57536
# 57537
# 57538
# 57539
# 57540
# ...

# %%
for i in df["genres"][:1]:
  print(i)
# Out:
# Adventure|Animation|Children|Comedy|Fantasy

# %%
df.at[0,"Adventure"]=0
df.at[0,"Adventure"]
# Out:
# np.float64(0.0)

# %%
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a29405eb924b> in <cell line: 0>()
# ----> 1 df.head(5)
#
# NameError: name 'df' is not defined

# %%
df.to_csv("movies_file.csv",index=False)

# %%
ddf
# Out:
#        movieId                               title      genres1    genres2  \
# 0            1                    Toy Story (1995)    Adventure  Animation
# 1            2                      Jumanji (1995)    Adventure   Children
# 2            3             Grumpier Old Men (1995)       Comedy    Romance
# 3            4            Waiting to Exhale (1995)       Comedy      Drama
# 4            5  Father of the Bride Part II (1995)       Comedy        NaN
# ...        ...                                 ...          ...        ...
# 62418   209157                           We (2018)        Drama        NaN
# 62419   209159           Window of the Soul (2001)  Documentary        NaN
# 62420   209163                    Bad Poems (2018)       Comedy      Drama
# 62421   209169                 A Girl Thing (2001)          (no     genres
# 62422   209171      Women of Devil's Island (1962)       Action  Adventure
#
# ...

# %%
movie_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/recommandation/content_base/content_base/movies_file.csv")

# %%
rating_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/recommandation/content_base/content_base/ratings.csv")

# %%
df_userweight = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/portfolio/recommandation/content_base/content_base/userweight.csv")

# %%
rating_df[rating_df["movieId"] == 296]["userId"].count()
# Out:
# np.int64(79672)

# %%
rating_df["movieId"].unique()
# Out:
# array([   296,    306,    307, ..., 139970, 200726, 200728])

# %%
movie_df["movieId"].unique()
# Out:
# array([     1,      2,      3, ..., 209163, 209169, 209171])
